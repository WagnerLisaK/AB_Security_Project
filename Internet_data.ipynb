# %%
import pandas as pd
#import psycopg2 as pg
#import sqlalchemy
#from sklearn.preprocessing import LabelEncoder
#from sklearn.ensemble import RandomForestClassifier
#from sklearn.model_selection import train_test_split
#from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
#import matplotlib as plt

# %%
data_df = pd.read_csv('Clean_Export_v2_convert_date.csv')
data_df
# Out:
#                                    IP_Address         DateTime        Date  \
# 0                                66.249.64.16  12/7/2021 16:41   12/7/2021
# 1                               66.249.73.137  12/9/2021 18:12   12/9/2021
# 2                                66.249.72.13  12/8/2021 19:44   12/8/2021
# 3                                66.249.64.16   12/7/2021 8:27   12/7/2021
# 4                                66.249.70.75  12/11/2021 6:24  12/11/2021
# ...                                       ...              ...         ...
# 7870  2600:1006:b101:c661:6151:de01:8388:ccbe  12/12/2021 5:48  12/12/2021
# 7871                            107.77.253.38   12/7/2021 0:41   12/7/2021
# 7872   2601:880:c000:32b0:4d5e:ecb4:d2a5:d7db  12/11/2021 1:32  12/11/2021
# 7873                             34.67.72.185  12/7/2021 11:23   12/7/2021
# 7874  2600:1006:b126:8306:50b4:9ef9:497e:187c  12/7/2021 22:07   12/7/2021
#
#           Time                                          UserAgent  \
# 0     16:41:58  Mozilla/5.0 (Linux; Android 6.0.1; Nexus 5X Bu...
# 1     18:12:04  Mozilla/5.0 (compatible; Googlebot/2.1; +http:...
# 2     19:44:21  Mozilla/5.0 (compatible; Googlebot/2.1; +http:...
# 3      8:27:21  Mozilla/5.0 (compatible; Googlebot/2.1; +http:...
# 4      6:24:39  Mozilla/5.0 (compatible; Googlebot/2.1; +http:...
# ...        ...                                                ...
# 7870   5:48:27  Mozilla/5.0 (iPhone; CPU iPhone OS 15_0_2 like...
# 7871   0:41:23  com.google.android.youtube/14.49.51(Linux; U; ...
# 7872   1:32:17  Mozilla/5.0 (iPhone; CPU iPhone OS 14_8 like M...
# 7873  11:23:23  Mozilla/5.0 (iPad; CPU OS 12_2 like Mac OS X) ...
# 7874  22:07:42  com.google.ios.youtube/16.45.4 (iPhone13,2; U;...
#
#                                             PreviousURL               Lat_Lng
# 0     /?gclid=CjwKCAjwgISIBhBfEiwALE19SUqMYbHF1_lIuO...                   NaN
# 1                                                     /                   NaN
# 2                                                     /                   NaN
# 3                                                     /                   NaN
# 4                                                     /                   NaN
# ...                                                 ...                   ...
# 7870                                                  /  28.538383,-81.378927
# 7871  /?gclid=CjwKCAiAhreNBhAYEiwAFGGKPFAim_kSUqkI_W...  28.538383,-81.378927
# 7872                                                  /  28.570294,-81.235361
# 7873                                                  /     0.000000,0.000000
# 7874  /?wbraid=ClIKCQiAhreNBhCgARJBAO6xh0K7LrRG_f62G...  28.538383,-81.378927
#
# [7875 rows x 7 columns]

# %%
# Populate "Lat" and "Lng" columns

location_df = data_df.copy()
location_df[['Lat','Lng']] = location_df.Lat_Lng.str.split(",",expand=True)
location_df
# Out:
#                                    IP_Address         DateTime        Date  \
# 0                                66.249.64.16  12/7/2021 16:41   12/7/2021
# 1                               66.249.73.137  12/9/2021 18:12   12/9/2021
# 2                                66.249.72.13  12/8/2021 19:44   12/8/2021
# 3                                66.249.64.16   12/7/2021 8:27   12/7/2021
# 4                                66.249.70.75  12/11/2021 6:24  12/11/2021
# ...                                       ...              ...         ...
# 7870  2600:1006:b101:c661:6151:de01:8388:ccbe  12/12/2021 5:48  12/12/2021
# 7871                            107.77.253.38   12/7/2021 0:41   12/7/2021
# 7872   2601:880:c000:32b0:4d5e:ecb4:d2a5:d7db  12/11/2021 1:32  12/11/2021
# 7873                             34.67.72.185  12/7/2021 11:23   12/7/2021
# 7874  2600:1006:b126:8306:50b4:9ef9:497e:187c  12/7/2021 22:07   12/7/2021
#
#           Time                                          UserAgent  \
# 0     16:41:58  Mozilla/5.0 (Linux; Android 6.0.1; Nexus 5X Bu...
# 1     18:12:04  Mozilla/5.0 (compatible; Googlebot/2.1; +http:...
# 2     19:44:21  Mozilla/5.0 (compatible; Googlebot/2.1; +http:...
# 3      8:27:21  Mozilla/5.0 (compatible; Googlebot/2.1; +http:...
# 4      6:24:39  Mozilla/5.0 (compatible; Googlebot/2.1; +http:...
# ...        ...                                                ...
# 7870   5:48:27  Mozilla/5.0 (iPhone; CPU iPhone OS 15_0_2 like...
# 7871   0:41:23  com.google.android.youtube/14.49.51(Linux; U; ...
# 7872   1:32:17  Mozilla/5.0 (iPhone; CPU iPhone OS 14_8 like M...
# 7873  11:23:23  Mozilla/5.0 (iPad; CPU OS 12_2 like Mac OS X) ...
# 7874  22:07:42  com.google.ios.youtube/16.45.4 (iPhone13,2; U;...
#
#                                             PreviousURL               Lat_Lng  \
# 0     /?gclid=CjwKCAjwgISIBhBfEiwALE19SUqMYbHF1_lIuO...                   NaN
# 1                                                     /                   NaN
# 2                                                     /                   NaN
# 3                                                     /                   NaN
# 4                                                     /                   NaN
# ...                                                 ...                   ...
# 7870                                                  /  28.538383,-81.378927
# 7871  /?gclid=CjwKCAiAhreNBhAYEiwAFGGKPFAim_kSUqkI_W...  28.538383,-81.378927
# 7872                                                  /  28.570294,-81.235361
# 7873                                                  /     0.000000,0.000000
# 7874  /?wbraid=ClIKCQiAhreNBhCgARJBAO6xh0K7LrRG_f62G...  28.538383,-81.378927
#
#             Lat         Lng
# 0           NaN         NaN
# 1           NaN         NaN
# 2           NaN         NaN
# 3           NaN         NaN
# 4           NaN         NaN
# ...         ...         ...
# 7870  28.538383  -81.378927
# 7871  28.538383  -81.378927
# 7872  28.570294  -81.235361
# 7873   0.000000    0.000000
# 7874  28.538383  -81.378927
#
# [7875 rows x 9 columns]

# %%
location_df.to_csv('location.csv')

# %%
prevurl_df = location_df.copy()
prevurl_df
# Out:
#                                    IP_Address         DateTime        Date  \
# 0                                66.249.64.16  12/7/2021 16:41   12/7/2021
# 1                               66.249.73.137  12/9/2021 18:12   12/9/2021
# 2                                66.249.72.13  12/8/2021 19:44   12/8/2021
# 3                                66.249.64.16   12/7/2021 8:27   12/7/2021
# 4                                66.249.70.75  12/11/2021 6:24  12/11/2021
# ...                                       ...              ...         ...
# 7870  2600:1006:b101:c661:6151:de01:8388:ccbe  12/12/2021 5:48  12/12/2021
# 7871                            107.77.253.38   12/7/2021 0:41   12/7/2021
# 7872   2601:880:c000:32b0:4d5e:ecb4:d2a5:d7db  12/11/2021 1:32  12/11/2021
# 7873                             34.67.72.185  12/7/2021 11:23   12/7/2021
# 7874  2600:1006:b126:8306:50b4:9ef9:497e:187c  12/7/2021 22:07   12/7/2021
#
#           Time                                          UserAgent  \
# 0     16:41:58  Mozilla/5.0 (Linux; Android 6.0.1; Nexus 5X Bu...
# 1     18:12:04  Mozilla/5.0 (compatible; Googlebot/2.1; +http:...
# 2     19:44:21  Mozilla/5.0 (compatible; Googlebot/2.1; +http:...
# 3      8:27:21  Mozilla/5.0 (compatible; Googlebot/2.1; +http:...
# 4      6:24:39  Mozilla/5.0 (compatible; Googlebot/2.1; +http:...
# ...        ...                                                ...
# 7870   5:48:27  Mozilla/5.0 (iPhone; CPU iPhone OS 15_0_2 like...
# 7871   0:41:23  com.google.android.youtube/14.49.51(Linux; U; ...
# 7872   1:32:17  Mozilla/5.0 (iPhone; CPU iPhone OS 14_8 like M...
# 7873  11:23:23  Mozilla/5.0 (iPad; CPU OS 12_2 like Mac OS X) ...
# 7874  22:07:42  com.google.ios.youtube/16.45.4 (iPhone13,2; U;...
#
#                                             PreviousURL               Lat_Lng  \
# 0     /?gclid=CjwKCAjwgISIBhBfEiwALE19SUqMYbHF1_lIuO...                   NaN
# 1                                                     /                   NaN
# 2                                                     /                   NaN
# 3                                                     /                   NaN
# 4                                                     /                   NaN
# ...                                                 ...                   ...
# 7870                                                  /  28.538383,-81.378927
# 7871  /?gclid=CjwKCAiAhreNBhAYEiwAFGGKPFAim_kSUqkI_W...  28.538383,-81.378927
# 7872                                                  /  28.570294,-81.235361
# 7873                                                  /     0.000000,0.000000
# 7874  /?wbraid=ClIKCQiAhreNBhCgARJBAO6xh0K7LrRG_f62G...  28.538383,-81.378927
#
#             Lat         Lng
# 0           NaN         NaN
# 1           NaN         NaN
# 2           NaN         NaN
# 3           NaN         NaN
# 4           NaN         NaN
# ...         ...         ...
# 7870  28.538383  -81.378927
# 7871  28.538383  -81.378927
# 7872  28.570294  -81.235361
# 7873   0.000000    0.000000
# 7874  28.538383  -81.378927
#
# [7875 rows x 9 columns]

# %%
prevurl_df[['gcl_wbr']] = prevurl_df.PreviousURL.str.extract(r'(\S{5})')
prevurl_df
# Out:
#                                    IP_Address         DateTime        Date  \
# 0                                66.249.64.16  12/7/2021 16:41   12/7/2021
# 1                               66.249.73.137  12/9/2021 18:12   12/9/2021
# 2                                66.249.72.13  12/8/2021 19:44   12/8/2021
# 3                                66.249.64.16   12/7/2021 8:27   12/7/2021
# 4                                66.249.70.75  12/11/2021 6:24  12/11/2021
# ...                                       ...              ...         ...
# 7870  2600:1006:b101:c661:6151:de01:8388:ccbe  12/12/2021 5:48  12/12/2021
# 7871                            107.77.253.38   12/7/2021 0:41   12/7/2021
# 7872   2601:880:c000:32b0:4d5e:ecb4:d2a5:d7db  12/11/2021 1:32  12/11/2021
# 7873                             34.67.72.185  12/7/2021 11:23   12/7/2021
# 7874  2600:1006:b126:8306:50b4:9ef9:497e:187c  12/7/2021 22:07   12/7/2021
#
#           Time                                          UserAgent  \
# 0     16:41:58  Mozilla/5.0 (Linux; Android 6.0.1; Nexus 5X Bu...
# 1     18:12:04  Mozilla/5.0 (compatible; Googlebot/2.1; +http:...
# 2     19:44:21  Mozilla/5.0 (compatible; Googlebot/2.1; +http:...
# 3      8:27:21  Mozilla/5.0 (compatible; Googlebot/2.1; +http:...
# 4      6:24:39  Mozilla/5.0 (compatible; Googlebot/2.1; +http:...
# ...        ...                                                ...
# 7870   5:48:27  Mozilla/5.0 (iPhone; CPU iPhone OS 15_0_2 like...
# 7871   0:41:23  com.google.android.youtube/14.49.51(Linux; U; ...
# 7872   1:32:17  Mozilla/5.0 (iPhone; CPU iPhone OS 14_8 like M...
# 7873  11:23:23  Mozilla/5.0 (iPad; CPU OS 12_2 like Mac OS X) ...
# 7874  22:07:42  com.google.ios.youtube/16.45.4 (iPhone13,2; U;...
#
#                                             PreviousURL               Lat_Lng  \
# 0     /?gclid=CjwKCAjwgISIBhBfEiwALE19SUqMYbHF1_lIuO...                   NaN
# 1                                                     /                   NaN
# 2                                                     /                   NaN
# 3                                                     /                   NaN
# 4                                                     /                   NaN
# ...                                                 ...                   ...
# 7870                                                  /  28.538383,-81.378927
# 7871  /?gclid=CjwKCAiAhreNBhAYEiwAFGGKPFAim_kSUqkI_W...  28.538383,-81.378927
# 7872                                                  /  28.570294,-81.235361
# 7873                                                  /     0.000000,0.000000
# 7874  /?wbraid=ClIKCQiAhreNBhCgARJBAO6xh0K7LrRG_f62G...  28.538383,-81.378927
#
#             Lat         Lng gcl_wbr
# 0           NaN         NaN   /?gcl
# 1           NaN         NaN     NaN
# 2           NaN         NaN     NaN
# 3           NaN         NaN     NaN
# 4           NaN         NaN     NaN
# ...         ...         ...     ...
# 7870  28.538383  -81.378927     NaN
# 7871  28.538383  -81.378927   /?gcl
# 7872  28.570294  -81.235361     NaN
# 7873   0.000000    0.000000     NaN
# 7874  28.538383  -81.378927   /?wbr
#
# [7875 rows x 10 columns]

# %%
prevurl_df.to_csv('prevurl.csv')

# %%
usragnt_df = prevurl_df.drop('PreviousURL', axis=1)
usragnt_df
# Out:
#                                    IP_Address         DateTime        Date  \
# 0                                66.249.64.16  12/7/2021 16:41   12/7/2021
# 1                               66.249.73.137  12/9/2021 18:12   12/9/2021
# 2                                66.249.72.13  12/8/2021 19:44   12/8/2021
# 3                                66.249.64.16   12/7/2021 8:27   12/7/2021
# 4                                66.249.70.75  12/11/2021 6:24  12/11/2021
# ...                                       ...              ...         ...
# 7870  2600:1006:b101:c661:6151:de01:8388:ccbe  12/12/2021 5:48  12/12/2021
# 7871                            107.77.253.38   12/7/2021 0:41   12/7/2021
# 7872   2601:880:c000:32b0:4d5e:ecb4:d2a5:d7db  12/11/2021 1:32  12/11/2021
# 7873                             34.67.72.185  12/7/2021 11:23   12/7/2021
# 7874  2600:1006:b126:8306:50b4:9ef9:497e:187c  12/7/2021 22:07   12/7/2021
#
#           Time                                          UserAgent  \
# 0     16:41:58  Mozilla/5.0 (Linux; Android 6.0.1; Nexus 5X Bu...
# 1     18:12:04  Mozilla/5.0 (compatible; Googlebot/2.1; +http:...
# 2     19:44:21  Mozilla/5.0 (compatible; Googlebot/2.1; +http:...
# 3      8:27:21  Mozilla/5.0 (compatible; Googlebot/2.1; +http:...
# 4      6:24:39  Mozilla/5.0 (compatible; Googlebot/2.1; +http:...
# ...        ...                                                ...
# 7870   5:48:27  Mozilla/5.0 (iPhone; CPU iPhone OS 15_0_2 like...
# 7871   0:41:23  com.google.android.youtube/14.49.51(Linux; U; ...
# 7872   1:32:17  Mozilla/5.0 (iPhone; CPU iPhone OS 14_8 like M...
# 7873  11:23:23  Mozilla/5.0 (iPad; CPU OS 12_2 like Mac OS X) ...
# 7874  22:07:42  com.google.ios.youtube/16.45.4 (iPhone13,2; U;...
#
#                    Lat_Lng        Lat         Lng gcl_wbr
# 0                      NaN        NaN         NaN   /?gcl
# 1                      NaN        NaN         NaN     NaN
# 2                      NaN        NaN         NaN     NaN
# 3                      NaN        NaN         NaN     NaN
# 4                      NaN        NaN         NaN     NaN
# ...                    ...        ...         ...     ...
# 7870  28.538383,-81.378927  28.538383  -81.378927     NaN
# 7871  28.538383,-81.378927  28.538383  -81.378927   /?gcl
# 7872  28.570294,-81.235361  28.570294  -81.235361     NaN
# 7873     0.000000,0.000000   0.000000    0.000000     NaN
# 7874  28.538383,-81.378927  28.538383  -81.378927   /?wbr
#
# [7875 rows x 9 columns]

# %%
usragnt_df['bot_yn'] = usragnt_df['UserAgent'].str.extract(r'(bot)')
usragnt_df
# Out:
#                                    IP_Address         DateTime        Date  \
# 0                                66.249.64.16  12/7/2021 16:41   12/7/2021
# 1                               66.249.73.137  12/9/2021 18:12   12/9/2021
# 2                                66.249.72.13  12/8/2021 19:44   12/8/2021
# 3                                66.249.64.16   12/7/2021 8:27   12/7/2021
# 4                                66.249.70.75  12/11/2021 6:24  12/11/2021
# ...                                       ...              ...         ...
# 7870  2600:1006:b101:c661:6151:de01:8388:ccbe  12/12/2021 5:48  12/12/2021
# 7871                            107.77.253.38   12/7/2021 0:41   12/7/2021
# 7872   2601:880:c000:32b0:4d5e:ecb4:d2a5:d7db  12/11/2021 1:32  12/11/2021
# 7873                             34.67.72.185  12/7/2021 11:23   12/7/2021
# 7874  2600:1006:b126:8306:50b4:9ef9:497e:187c  12/7/2021 22:07   12/7/2021
#
#           Time                                          UserAgent  \
# 0     16:41:58  Mozilla/5.0 (Linux; Android 6.0.1; Nexus 5X Bu...
# 1     18:12:04  Mozilla/5.0 (compatible; Googlebot/2.1; +http:...
# 2     19:44:21  Mozilla/5.0 (compatible; Googlebot/2.1; +http:...
# 3      8:27:21  Mozilla/5.0 (compatible; Googlebot/2.1; +http:...
# 4      6:24:39  Mozilla/5.0 (compatible; Googlebot/2.1; +http:...
# ...        ...                                                ...
# 7870   5:48:27  Mozilla/5.0 (iPhone; CPU iPhone OS 15_0_2 like...
# 7871   0:41:23  com.google.android.youtube/14.49.51(Linux; U; ...
# 7872   1:32:17  Mozilla/5.0 (iPhone; CPU iPhone OS 14_8 like M...
# 7873  11:23:23  Mozilla/5.0 (iPad; CPU OS 12_2 like Mac OS X) ...
# 7874  22:07:42  com.google.ios.youtube/16.45.4 (iPhone13,2; U;...
#
#                    Lat_Lng        Lat         Lng gcl_wbr bot_yn
# 0                      NaN        NaN         NaN   /?gcl    bot
# 1                      NaN        NaN         NaN     NaN    bot
# 2                      NaN        NaN         NaN     NaN    bot
# 3                      NaN        NaN         NaN     NaN    bot
# 4                      NaN        NaN         NaN     NaN    bot
# ...                    ...        ...         ...     ...    ...
# 7870  28.538383,-81.378927  28.538383  -81.378927     NaN    NaN
# 7871  28.538383,-81.378927  28.538383  -81.378927   /?gcl    NaN
# 7872  28.570294,-81.235361  28.570294  -81.235361     NaN    NaN
# 7873     0.000000,0.000000   0.000000    0.000000     NaN    NaN
# 7874  28.538383,-81.378927  28.538383  -81.378927   /?wbr    NaN
#
# [7875 rows x 10 columns]

# %%
usragnt_df = usragnt_df.drop('bot_yn', axis=1)
usragnt_df['Gbot_yn'] = usragnt_df['UserAgent'].str.extract(r'(Googlebot)')
usragnt_df['bot_yn'] = usragnt_df['bot_yn'].str.replace('bot','y')
usragnt_df['bot_yn'] = usragnt_df['bot_yn'].fillna('n')
usragnt_df
# Out:
#                                    IP_Address         DateTime        Date  \
# 0                                66.249.64.16  12/7/2021 16:41   12/7/2021
# 1                               66.249.73.137  12/9/2021 18:12   12/9/2021
# 2                                66.249.72.13  12/8/2021 19:44   12/8/2021
# 3                                66.249.64.16   12/7/2021 8:27   12/7/2021
# 4                                66.249.70.75  12/11/2021 6:24  12/11/2021
# ...                                       ...              ...         ...
# 7870  2600:1006:b101:c661:6151:de01:8388:ccbe  12/12/2021 5:48  12/12/2021
# 7871                            107.77.253.38   12/7/2021 0:41   12/7/2021
# 7872   2601:880:c000:32b0:4d5e:ecb4:d2a5:d7db  12/11/2021 1:32  12/11/2021
# 7873                             34.67.72.185  12/7/2021 11:23   12/7/2021
# 7874  2600:1006:b126:8306:50b4:9ef9:497e:187c  12/7/2021 22:07   12/7/2021
#
#           Time                                          UserAgent  \
# 0     16:41:58  Mozilla/5.0 (Linux; Android 6.0.1; Nexus 5X Bu...
# 1     18:12:04  Mozilla/5.0 (compatible; Googlebot/2.1; +http:...
# 2     19:44:21  Mozilla/5.0 (compatible; Googlebot/2.1; +http:...
# 3      8:27:21  Mozilla/5.0 (compatible; Googlebot/2.1; +http:...
# 4      6:24:39  Mozilla/5.0 (compatible; Googlebot/2.1; +http:...
# ...        ...                                                ...
# 7870   5:48:27  Mozilla/5.0 (iPhone; CPU iPhone OS 15_0_2 like...
# 7871   0:41:23  com.google.android.youtube/14.49.51(Linux; U; ...
# 7872   1:32:17  Mozilla/5.0 (iPhone; CPU iPhone OS 14_8 like M...
# 7873  11:23:23  Mozilla/5.0 (iPad; CPU OS 12_2 like Mac OS X) ...
# 7874  22:07:42  com.google.ios.youtube/16.45.4 (iPhone13,2; U;...
#
#                    Lat_Lng        Lat         Lng gcl_wbr bot_yn
# 0                      NaN        NaN         NaN   /?gcl      y
# 1                      NaN        NaN         NaN     NaN      y
# 2                      NaN        NaN         NaN     NaN      y
# 3                      NaN        NaN         NaN     NaN      y
# 4                      NaN        NaN         NaN     NaN      y
# ...                    ...        ...         ...     ...    ...
# 7870  28.538383,-81.378927  28.538383  -81.378927     NaN      n
# 7871  28.538383,-81.378927  28.538383  -81.378927   /?gcl      n
# 7872  28.570294,-81.235361  28.570294  -81.235361     NaN      n
# 7873     0.000000,0.000000   0.000000    0.000000     NaN      n
# 7874  28.538383,-81.378927  28.538383  -81.378927   /?wbr      n
#
# [7875 rows x 10 columns]

# %%
temp1['bot_yn'] = temp1['bot_yn'].str.replace('bot','y')
temp1
# Out:
# C:\Users\lkwor\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                                                                                                                                                                                                 UserAgent  \
# 0  Mozilla/5.0 (Linux; Android 6.0.1; Nexus 5X Build/MMB29P) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Mobile Safari/537.36 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)
#
#   bot_yn
# 0      y

# %%
if

# %%
dataviz_df = prevurl_df.drop('PreviousURL', axis=1)
dataviz_df
# Out:
#                                    IP_Address         DateTime        Date  \
# 0                                66.249.64.16  12/7/2021 16:41   12/7/2021
# 1                               66.249.73.137  12/9/2021 18:12   12/9/2021
# 2                                66.249.72.13  12/8/2021 19:44   12/8/2021
# 3                                66.249.64.16   12/7/2021 8:27   12/7/2021
# 4                                66.249.70.75  12/11/2021 6:24  12/11/2021
# ...                                       ...              ...         ...
# 7870  2600:1006:b101:c661:6151:de01:8388:ccbe  12/12/2021 5:48  12/12/2021
# 7871                            107.77.253.38   12/7/2021 0:41   12/7/2021
# 7872   2601:880:c000:32b0:4d5e:ecb4:d2a5:d7db  12/11/2021 1:32  12/11/2021
# 7873                             34.67.72.185  12/7/2021 11:23   12/7/2021
# 7874  2600:1006:b126:8306:50b4:9ef9:497e:187c  12/7/2021 22:07   12/7/2021
#
#           Time                                          UserAgent  \
# 0     16:41:58  Mozilla/5.0 (Linux; Android 6.0.1; Nexus 5X Bu...
# 1     18:12:04  Mozilla/5.0 (compatible; Googlebot/2.1; +http:...
# 2     19:44:21  Mozilla/5.0 (compatible; Googlebot/2.1; +http:...
# 3      8:27:21  Mozilla/5.0 (compatible; Googlebot/2.1; +http:...
# 4      6:24:39  Mozilla/5.0 (compatible; Googlebot/2.1; +http:...
# ...        ...                                                ...
# 7870   5:48:27  Mozilla/5.0 (iPhone; CPU iPhone OS 15_0_2 like...
# 7871   0:41:23  com.google.android.youtube/14.49.51(Linux; U; ...
# 7872   1:32:17  Mozilla/5.0 (iPhone; CPU iPhone OS 14_8 like M...
# 7873  11:23:23  Mozilla/5.0 (iPad; CPU OS 12_2 like Mac OS X) ...
# 7874  22:07:42  com.google.ios.youtube/16.45.4 (iPhone13,2; U;...
#
#                    Lat_Lng        Lat         Lng gcl_wbr
# 0                      NaN        NaN         NaN   /?gcl
# 1                      NaN        NaN         NaN     NaN
# 2                      NaN        NaN         NaN     NaN
# 3                      NaN        NaN         NaN     NaN
# 4                      NaN        NaN         NaN     NaN
# ...                    ...        ...         ...     ...
# 7870  28.538383,-81.378927  28.538383  -81.378927     NaN
# 7871  28.538383,-81.378927  28.538383  -81.378927   /?gcl
# 7872  28.570294,-81.235361  28.570294  -81.235361     NaN
# 7873     0.000000,0.000000   0.000000    0.000000     NaN
# 7874  28.538383,-81.378927  28.538383  -81.378927   /?wbr
#
# [7875 rows x 9 columns]

# %%
prevurl_df.to_csv('dataviz.csv')
